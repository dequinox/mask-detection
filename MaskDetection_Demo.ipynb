# %% [markdown]
# #YOLO-based Mask Detection Model
# ### Doro Umarov, Timur Galiev

# %%
import os
import torch
from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.12.1+cu113 CPU

# %%
# !git clone https://github.com/roboflow-ai/yolov3  # clone
# !git clone https://github.com/dequinox/maskdetection
# Out:
# fatal: destination path 'yolov3' already exists and is not an empty directory.
# Cloning into 'maskdetection'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 31 (delta 3), reused 28 (delta 3), pack-reused 0
# Unpacking objects: 100% (31/31), done.

# %% [markdown]
# ---
# ####You will need to download the pretrained model from [here](https://drive.google.com/drive/folders/1zSC8j9dU0Urm38C8_U83_v3UW6Oo1vxG). Then, put it in the root folder.
#
# If you are using google colab, run the 2 blocks below to move the file from your drive to the colab as it is much faster. You will need to have the weights file downloaded to your drive.

# %%
# connect Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cp /content/gdrive/MyDrive/last_copy.pt ./

# %% [markdown]
# ---

# %%
# %cd ..
# Out:
# /content

# %%
from maskdetection.maskDetect import MaskDetector
from google.colab.patches import cv2_imshow
maskDet = MaskDetector("last_copy.pt", "output")
# Out:
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients

# %%
img = maskDet.detect_mask("maskdetection/images/maskedman.jpg")
cv2_imshow(img)
# Out:
# image 1/1 maskdetection/images/maskedman.jpg:
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# <PIL.Image.Image image mode=RGB size=700x700 at 0x7F7020422990>
